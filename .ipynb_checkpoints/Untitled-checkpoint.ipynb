# %%
# !python --version
import sys
print(sys.executable)
# Out:
# Python 3.10.19
# C:\College\AIE\envs\ai-assistant\python.exe

# %%
# !python -m pip install --upgrade pip

# %%
import numpy
import streamlit
import PyPDF2
import faiss
import langchain
print("All imports work!")
# Out:
# All imports work!

# %%
from PyPDF2 import PdfReader

reader = PdfReader("docs/sample_medical_info.pdf")  # or PDF file
text = ""
for page in reader.pages:
    text += page.extract_text()

print(text[:500])  # print first 500 chars
# Out:
# # Medical Clinic Information Guide
#
# ## About Our Clinic
#
# Welcome to HealthCare Plus Medical Center. We are a comprehensive healthcare facility offering a
# wide range of medical services to our community.
#
# ### Our Services
#
# #### General Consultation
# Our general practitioners provide comprehensive primary care services including:
# - Annual health checkups
# - Common illness diagnosis and treatment
# - Preventive care and health screenings
# - Vaccination services
# - Health counseli

# %%
import numpy as np
arr = np.array([1, 2, 3])
print(arr * 2)
# Out:
# [2 4 6]

# %%
from supabase import create_client

url = ""
key = ""
supabase = create_client(url, key)

data = supabase.table("customers").select("*").execute()
print(data)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[6], line 7
#       4 key = "sb_publishable_Ga3Q6Ck0MlkZuK1Y9RUhuQ_NjM7s4Ct"
#       5 supabase = create_client(url, key)
# ----> 7 data = supabase.table("customers").select("*").execute()
#       8 print(data)
#
# File C:\College\AIE\envs\ai-assistant\lib\site-packages\postgrest\_sync\request_builder.py:53, in SyncQueryRequestBuilder.execute(self)
#      51     else:
#      52         json_obj = model_validate_json(APIErrorFromJSON, r.content)
# ---> 53         raise APIError(dict(json_obj))
#      54 except ValidationError as e:
#      55     raise APIError(generate_default_error_message(r))
#
# APIError: {'message': "Could not find the table 'public.customers' in the schema cache", 'code': 'PGRST205', 'hint': None, 'details': None}

# %%
from supabase import create_client

url = "https://qcqtedtaxkyddzjjfimr.supabase.co"
key = "sb_publishable_Ga3Q6Ck0MlkZuK1Y9RUhuQ_NjM7s4Ct"
supabase = create_client(url, key)

# Test customers table
res = supabase.table("customers").select("*").execute()
print(res)

# Test bookings table
res2 = supabase.table("bookings").select("*").execute()
print(res2)
