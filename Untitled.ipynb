# %%
# !python --version
import sys
print(sys.executable)
# Out:
# Python 3.10.19
# C:\College\AIE\envs\ai-assistant\python.exe

# %%
# !python -m pip install --upgrade pip

# %%
import numpy
import streamlit
import PyPDF2
import faiss
import langchain
print("All imports work!")
# Out:
# All imports work!

# %%
from PyPDF2 import PdfReader

reader = PdfReader("docs/sample_medical_info.pdf")  # or PDF file
text = ""
for page in reader.pages:
    text += page.extract_text()

print(text[:500])  # print first 500 chars
# Out:
# # Medical Clinic Information Guide
#
# ## About Our Clinic
#
# Welcome to HealthCare Plus Medical Center. We are a comprehensive healthcare facility offering a
# wide range of medical services to our community.
#
# ### Our Services
#
# #### General Consultation
# Our general practitioners provide comprehensive primary care services including:
# - Annual health checkups
# - Common illness diagnosis and treatment
# - Preventive care and health screenings
# - Vaccination services
# - Health counseli

# %%
import numpy as np
arr = np.array([1, 2, 3])
print(arr * 2)
# Out:
# [2 4 6]

# %%
from supabase import create_client

url = "https://vyqactowwasvpefefsru.supabase.co"
key = "sb_publishable_IuHFmzxkJyut0QA0TGj1oQ_Amll0a-u"

supabase = create_client(url, key)

# Test customers table
res = supabase.table("customers").select("*").execute()
print(res)

# Test bookings table
res2 = supabase.table("bookings").select("*").execute()
print(res2)
# Out:
# data=[] count=None
# data=[] count=None

# %%
import groq
print(groq.__version__)
# Out:
# 1.0.0

# %%
import langchain, langchain_core, langchain_community, langchain_groq
print(langchain.__version__, langchain_core.__version__, langchain_community.__version__, langchain_groq.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 import langchain, langchain_core, langchain_community, langchain_groq
# ----> 2 print(langchain.__version__, langchain_core.__version__, langchain_community.__version__, langchain_groq.__version__)
#
# AttributeError: module 'langchain_groq' has no attribute '__version__'
